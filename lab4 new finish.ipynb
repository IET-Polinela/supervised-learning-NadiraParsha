# %%
from google.colab import auth
auth.authenticate_user()

# Konfigurasi identitas GitHub
# !git config --global user.email "nadiraparshasalsabila@gmail.com"
# !git config --global user.name "NadiraParsha"

# Clone repository dengan URL yang benar
# !git clone https://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@github.com/IET-Polinela/supervised-learning-NadiraParsha.git
# Masuk ke direktori repository
# %cd supervised-learning-NadiraParsha
# Out:
# Cloning into 'supervised-learning-NadiraParsha'...
# ...
# /content/supervised-learning-NadiraParsha

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a4640a8-2c37-496d-90c6-0a92a8309b7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a4640a8-2c37-496d-90c6-0a92a8309b7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %%writefile comporation_models_and_conclusion.py
# Out:
# Writing comporation_models_and_conclusion.py

# %%
# !git add .
# !git commit -m “LAB_4”
# !git push origin main
# Out:
# [main (root-commit) f7eb375] “LAB_4”
#  9 files changed, 2135 insertions(+)
#  create mode 100644 Feature_scaling.py
#  create mode 100644 HousePricing.csv
#  create mode 100644 KNN_regression.py
#  create mode 100644 comporation_models_and_conclusion.py
#  create mode 100644 data_processing.py
#  create mode 100644 data_understanding.py
#  create mode 100644 linear_regression.py
#  create mode 100644 outlier_handling.py
#  create mode 100644 polynomial_regression.py
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (11/11), done.
# Writing objects: 100% (11/11), 95.99 KiB | 3.84 MiB/s, done.
# Total 11 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/IET-Polinela/supervised-learning-NadiraParsha.git
#  * [new branch]      main -> main

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !find /content/drive -name "LAB4_23758049.ipynb"

# %%
# !find /content/drive -name "lab4 new finish.ipynb"
# Out:
# /content/drive/MyDrive/Colab Notebooks/lab4 new finish.ipynb

# %%
# %cd /content/supervised-learning-NadiraParsha
# !git add .
# !git commit -m "Menambahkan LAB3_23758049.ipynb dari Google Drive"
# !git push origin main
# Out:
# /content/supervised-learning-NadiraParsha
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !cp "/content/drive/My Drive/lab4 new finish.ipynb" /content/supervised-learning-NadiraParsha/
# Out:
# cp: cannot stat '/content/drive/My Drive/lab4 new finish.ipynb': No such file or directory

# %%
# !ls "/content/drive/My Drive/"
# Out:
# '10.1.4 Packet Tracer - Configure Initial Router Settings.pka'
# '10.3.4 Packet Tracer - Connect a Router to a LAN.pka'
# '10.3.5 Packet Tracer - Troubleshoot Default Gateway Issues.pka'
# '10.4.3 Packet Tracer - Basic Device Configuration.pka'
# '10.4.4 Lab - Build a Switch and Router Network.docx'
# '11.10.1 Packet Tracer - Design and Implement a VLSM Addressing Scheme.pka'
# '11.10.2 Lab - Design and Implement a VLSM Addressing Scheme.docx'
# '11.10.2 Packet Tracer - Design and Implement a VLSM Addressing Scheme - Physical Mode.pka'
# '11.5.5 Packet Tracer - Subnet an IPv4 Network.pka'
#  11.6.6-lab---calculate-ipv4-subnets.docx
# '11.7.5 Packet Tracer - Subnetting Scenario.pka'
# '11.9.3 Packet Tracer - VLSM Design and Implementation Practice.pka'
# '12.4.5 Packet Tracer - Basic Device Configuration.pka'
# '12.6.6 Packet Tracer - Configure IPv6 Addressing.pka'
# '12.7.4 Lab - Identify IPv6 Addresses.docx'
# ...
